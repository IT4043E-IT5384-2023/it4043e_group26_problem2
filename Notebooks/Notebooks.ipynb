# %%
# !git clone https://github.com/IT4043E-IT5384-2023/it4043e_group26_problem2.git
# Out:
# Cloning into 'it4043e_group26_problem2'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 59 (delta 25), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (59/59), 829.71 KiB | 8.47 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %%
cd /content/it4043e_group26_problem2
# Out:
# /content/it4043e_group26_problem2

# %%
import os
path = "/content/it4043e_group26_problem2/data"
os.mkdir(path)

# %%
pip install -r requirement.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.7 MB/s eta 0:00:00
# ...

# %%
pip install tweety-ns

# %%
pip install https://github.com/mahrtayyab/tweety/archive/main.zip --upgrade
# Out:
# ...
#      - 82.0 kB 3.2 MB/s 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for tweety-ns: filename=tweety_ns-0.9.9.9.5-py3-none-any.whl size=57625 sha256=3acdfd6c61043b7d5696f6e3242413e8d87599a6660b56bb4419f05a6d35aaee
#   Stored in directory: /tmp/pip-ephem-wheel-cache-iuzrfhgf/wheels/28/67/45/f148cacb1f5c1e58fbd5654ab9db44dc8ed08a3aeef726e8ac
# Successfully built tweety-ns
# ...
#   Attempting uninstall: tweety-ns
#     Found existing installation: tweety-ns 0.9.9.5
#     Uninstalling tweety-ns-0.9.9.5:
#       Successfully uninstalled tweety-ns-0.9.9.5
# ...

# %%
# !python tweet_crawler.py
# Out:
# Read YAML config successfully
# Crawling with keyword 'Bitcoin'
